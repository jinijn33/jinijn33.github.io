# %%
for (x, y) in [('a',1), ('b',2), ('c',3), ('d',4)]:
    print (x)
# Out:
# a
# b
# c
# d

# %%
for x in range(5):
    print (x)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
mylist = [10, 20, 30, 40]

for i in range(len(mylist)):
    print (i), mylist[i]
# Out:
# 0
# 1
# 2
# 3

# %%
mylist = [10, 20, 30, 40]

for (i, item) in enumerate(mylist):
    print (i), (item)
# Out:
# 0
# 1
# 2
# 3
