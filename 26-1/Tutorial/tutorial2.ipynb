# %% [markdown]
# ### Lists

# %%
li = ["abc", 23, 4.34, 23] #리스트 생성

# %%
li[1] = 45 #리스트 자리값 찾기

# %%
li
# Out:
# ['abc', 45, 4.34, 23]

# %% [markdown]
# ### Tuples

# %%
t = (23, "abc", 4.56, (2,3), "def") #튜플 생성

# %%
t[2] = 3.14 #튜플의 값 수정시 오류 발생
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 t[2] = 3.14
#
# TypeError: 'tuple' object does not support item assignment

# %%
t = (23, "abc", 3.14, (2,3), "def") #튜플 자체를 수정해야됨

# %%
li = [1, 11, 3, 4, 5]

# %%
li.append("a") #리스트의 마지막에  a 추가

# %%
li
# Out:
# [1, 11, 3, 4, 5, 'a']

# %%
li.insert(2,'i') #자리지정, i 추가

# %%
li
# Out:
# [1, 11, 'i', 3, 4, 5, 'a']

# %%
li.extend([9, 8, 7]) #여러개의 항목을 리스트 안에 한번에 더하기

# %%
li
# Out:
# [1, 11, 'i', 3, 4, 5, 'a', 9, 8, 7]

# %%
li.append([10, 11, 12]) #여러개의 항목이 있는 리스트를 리스트 안에 추가하기

# %%
li
# Out:
# [1, 11, 'i', 3, 4, 5, 'a', 9, 8, 7, [10, 11, 12]]

# %%
li = ['a', 'b', 'c', 'b']

# %%
li.index('b') #리스트 안에 b 의 위치 찾기
# Out:
# 1

# %%
li.count('b') #리스트 안의  b 의 갯수 세기
# Out:
# 2

# %%
li.remove('b') # 리스트 안의 b 삭제 - 인덱스 넘버가 빠른거부터

# %%
li
# Out:
# ['a', 'c', 'b']

# %%
li = [5, 2, 6, 8]

# %%
li.reverse() #역순

# %%
li
# Out:
# [8, 6, 2, 5]

# %%
li.sort() #섞기

# %%
li
# Out:
# [2, 5, 6, 8]
